# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("twins.csv")
df = df.sort_values(by=['PrimeA'])
df = df.reset_index(drop=True)
plt.plot(df["PrimeA"])
plt.xlabel("Number of the first twin prime")
plt.ylabel("Primenumber")
# Out:
# Text(0, 0.5, 'Primenumber')
